# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
data = pd.read_csv("/dbfs/FileStore/tables/nfg5a3np1477092781030/code_challenge_train.csv")
docsY = data['description_y'].tolist()
docsX = data['description_x'].tolist()
docsTX = data['ticker_x'].tolist()
docsTY = data['ticker_y'].tolist()
#docsSec = data['same_security']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizerone = CountVectorizer(stop_words='english').fit(['docsX','docsY'])
vectorizertwo = CountVectorizer(stop_words='english').fit(['docsTX','docsTY'])
#vectorizerone = CountVectorizer(stop_words='english').fit(docsX)

# %%
#vectorizerone.fit(docsX,docsY)
ticker_freq_matrix = vectorizertwo.fit_transform(docsTX,docsTY)
print("TF of Ticker:",vectorizertwo.vocabulary_)

# %%
#doc_term_matrix = vectorizerone.fit_transform(docsX,docsY)
doc_term_matrix = vectorizerone.fit_transform(docsX)
print ("TF of all:" ,vectorizerone.vocabulary_)

# %%
freak_term_matrix = vectorizerone.transform(docstest)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf = TfidfTransformer(norm="l2")
tfidf.fit(freak_term_matrix)

print ("IDF:", tfidf.idf_)

# %%
tf_idf_matrix = tfidf.transform(freak_term_matrix)
print tf_idf_matrix.todense()

# %%
print(freak_term_matrix.todense())

# %%
shmatrix = vectorizerone.transform(docstest)
print(shmatrix)

# %%
from IPython.display import display
display(shmatrix.todense())

# %%
smatrix = vectorizerone.transform(docsX)
smatrixone = vectorizerone.transform(docsY)
smatrixtwo = vectorizertwo.transform(docsTX)
smatrixthree = vectorizertwo.transform(docsTY)
#smatrix = vectorizertwo.transform(ticker_freq_matrix)

# %%
smatrix
smatrixone
smatrixtwo
smatrixthree

# %%
smatrix.todense()
smatrixone.todense()
smatrixtwo.todense()
smatrixthree.todense()

# %%
print(smatrix)
print(smatrixone)
print(smatrixtwo)
print(smatrixtwo)

# %%
#freq_term_matrix = vectorizerone.transform(docs)

# %%
#print (freq_term_matrix.todense())
print (doc_term_matrix.todense())

# %%
print(ticker_freq_matrix.todense())

# %%
#from sklearn.feature_extraction.text import TfidfTransformer
#tfidffour = TfidfTransformer(norm="l2")
#tfidffour.fit(doc_term_matrix)
#print ("IDF score:", tfidffour.idf_)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidfsix = TfidfTransformer(norm="l2")
tfidfsix.fit(doc_term_matrix)
print ("IDF score:", tfidfsix.idf_)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidftwo = TfidfTransformer(norm="l2")
tfidftwo.fit(ticker_freq_matrix)
print ("IDF score:", tfidftwo.idf_)

# %%
tf_idf_matrix = tfidfsix.transform(doc_term_matrix)
print (tf_idf_matrix.todense())

# %%
tf_idf_matrixtwo = tfidftwo.transform(ticker_freq_matrix)
print(tf_idf_matrixtwo.todense())

# %%
import numpy as np
def cosine_distance(tf_idf_matrix,tf_idf_matrixtwo):
  return np.dot(tf_idf_matrix, tf_idf_matrixtwo) / (math.sqrt(numpy.dot(tf_idf_matrix,tf_idf_matrix)) * math.sqrt(numpy.dot(tf_idf_matrix,tf_idf_matrixtwo)))

# %%
#print (tf_idf_matrix * tf_idf_matrixtwo)
tf_idf_matrix.shape
tf_idf_matrixtwo.shape

# %% [markdown]
# TEST DATA - TFIDF for DESC X

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
data = pd.read_csv("/dbfs/FileStore/tables/1jan81qj1477098178857/code_challenge_test.csv")
docstest = data['description_x'].tolist()

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizertest = CountVectorizer(stop_words='english')
#vectorizertest = CountVectorizer(stop_words=None)

# %%
vectorizertest

# %%
document_term_matrixnew = vectorizertest.fit_transform(docstest)
print ("TF of Description X:" ,vectorizertest.vocabulary_)

# %%
freq_term_matrix = vectorizertest.transform(docstest)

# %%
print (freq_term_matrix.todense())

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer(norm="l2")
tfidf.fit(freq_term_matrix)
print ("IDF score:", tfidf.idf_)

# %%
tf_idf_matrix = tfidf.transform(freq_term_matrix)
print (tf_idf_matrix.todense())

# %% [markdown]
# TEST DATA - TFIDF for DESC Y

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
data = pd.read_csv("/dbfs/FileStore/tables/1jan81qj1477098178857/code_challenge_test.csv")
docstestone = data['description_y'].tolist()

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizertestone = CountVectorizer(stop_words='english')

# %%
vectorizertestone

# %%
document_term_matrixtwo = vectorizertestone.fit_transform(docstestone)
print ("TF of Description X:" ,vectorizertestone.vocabulary_)

# %%
freq_term_matrixnew = vectorizertestone.transform(docstestone)

# %%
print (freq_term_matrixnew.todense())

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer(norm="l2")
tfidf.fit(freq_term_matrixnew)
print ("IDF score:", tfidf.idf_)

# %%
tf_idf_matrix = tfidf.transform(freq_term_matrixnew)
print (tf_idf_matrix.todense())

# %% [markdown]
# TICKER DATA

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
data = pd.read_csv("/dbfs/FileStore/tables/nfg5a3np1477092781030/code_challenge_train.csv")
docstickerx = data['ticker_x']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizerticker = CountVectorizer(stop_words=None)

# %%
vectorizerticker

# %%
document_term_matrixticker = vectorizerticker.fit_transform(docstickerx)
print ("TF of Ticker X:" ,vectorizerticker.vocabulary_)

# %%
freq_term_matrixticker= vectorizerticker.transform(docstickerx)
print (freq_term_matrixticker.todense())

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidfone = TfidfTransformer(norm="l2")
tfidfone.fit(freq_term_matrixticker)
print ("IDF score:", tfidfone.idf_)

# %%
#tf_idf_matrix = tfidf.transform(freq_term_matrixticker)
#print (tf_idf_matrix.todense())

# %% [markdown]
# for TICKER Y

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
data = pd.read_csv("/dbfs/FileStore/tables/nfg5a3np1477092781030/code_challenge_train.csv")
docstickery = data['ticker_y']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizertickery = CountVectorizer(stop_words=None)

# %%
vectorizertickery

# %%
document_term_matrixtickery = vectorizertickery.fit_transform(docstickery)
print ("TF of Ticker Y:" ,vectorizertickery.vocabulary_)

# %%
freq_term_matrixtickery= vectorizertickery.transform(docstickery)
print (freq_term_matrixtickery.todense())

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer(norm="l2")
tfidf.fit(freq_term_matrixtickery)
print ("IDF score:", tfidf.idf_)

# %%
tf_idf_matrix = tfidf.transform(freq_term_matrixtickery)
print (tf_idf_matrix.todense())

# %% [markdown]
# SECURITY

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
data = pd.read_csv("/dbfs/FileStore/tables/nfg5a3np1477092781030/code_challenge_train.csv")
docssec = data['same_security']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizertickersec = CountVectorizer(stop_words=None)

# %%
vectorizertickersec

# %%
from sklearn import preprocessing

# %%
lb = preprocessing.LabelBinarizer()

# %%
lb.fit(['docssec'])

# %%
lb.classes_

# %%
lb.fit_transform(['docssec'])
print(docssec.shape)

# %%
import numpy as np

# %%
from sklearn.svm import SVC

# %%
from sklearn.metrics import roc_auc_score

# %%
from datetime import date

# %%
clf = SVC(probability=True, kernel='rbf')

# %%
clf.fit(doc_term_matrix,ticker_freq_matrix)

# %%
predictions = clf.predict_proba(freq_term_matrixticker)
print('ROC-AUC yields ' + str(roc_auc_score(docssec, predictions[:,1])))

# %%
#pairwise_similarity = tfidftwo * tfidftwo.idf_

# %%
import math
import numpy as np
def cosine_distance(tfidf,tfidfone):
  return np.dot(tfidf, tfidfone) / (math.sqrt(np.dot(tfidf,tfidfone)) * math.sqrt(np.dot(tfidf,tfidfone)))

# %%
print(cosine_distance(90,90))
#print(cosine_distance(document_term_matrix,ticker_freq_matrix))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
docsnewone = data['description_y']
