# %%
"""
Hi

Thank you for taking the time to apply to Quovo. We like to send potential candidates a SHORT coding test/exercise so 
we could get a sense of how they approach problems. This also gives you the a good opportunity to see if Quovo-style 
challenges are a good fit for you. Don't go crazy on time, we'd just like to see enough progress on it where we can 
all have a conversation looking at your code together and talk about how you attacked the problem.

The concept:

In each row of the included datasets, products X and Y are considered to refer to the same security if 
they have the same ticker, even if the descriptions don't exactly match. 

Your challenge is to use these descriptions to predict whether each pair in the test set also refers to the 
same security. The difficulty of predicting each row will vary significantly, so please do not aim for 100% accuracy. 
There are several good ways to approach this, and we have no preference between them. 
The only requirement is that you do all of the work in this file, and return it to us.

Hint: Don't be afraid if you have no experience with text processing. You are in the majority. Check out this algorithm, 
and see how far you can go with it:
https://en.wikipedia.org/wiki/Tf–idf
http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

Good luck!
"""

import pandas as pd
from IPython.display import display

train = pd.DataFrame.from_csv('code_challenge_train.csv')
test = pd.DataFrame.from_csv('code_challenge_test.csv')

display(train)
# Out:
#                                           description_x  \
# 0                        first trust dow jones internet
# 1                   schwab intl large company index etf
# 2                          vanguard small cap index adm
# 3     duke energy corp new com new isin #us4 sedol #...
# 4                                      visa inc class a
# 5                          ford motor co new div: 0.600
# 6                              united states steel corp
# 7           vanguard total international bond index etf
# 8                          schwab strategic tr us sml c
# 9                                     mfs value fd cl i
# 10                      oppenheimer dev markets class a
# 11                                       genomic health
# 12                      spdr barclays international etf
# 13                                  kraft heinz company
# 14    vanguard total bond market index fund admiral ...
# 15    vanguard intermediate-term investment-grade fu...
# 16                                   baidu inc spon adr
# 17                                     novartis ag- reg
# 18                                         seaspan corp
# 19             vanguard total bond market index admiral
# 20                         mfs muni high income fd cl i
# 21                                      metlife inc com
# 22              russell gbl real estate securities cl s
# 23    vanguard short-term investment-grade fund admi...
# 24                               spdr s&p 500 etf trust
# 25                                 pimco total return a
# 26                                           intel corp
# 27              vanguard 500 index fund - admiral class
# 28                                  paypal holdings inc
# 29                                    pim total rt inst
# ...                                                 ...
# 2112                                     pfizer inc com
# 2113                         pimco fds income fund cl d
# 2114                         vanguard mid-cap value etf
# 2115                     wisdomtree investments inc com
# 2116                  merrimack pharmaceuticals inc com
# 2117                        ishares russell 1000 growth
# 2118                                 exxon mobil corp -
# 2119            blackrock high yield bond portfolio svc
# 2120                   pimco commodity real return inst
# 2121              vanguard small-cap index fund admiral
# 2122                                          pg&e corp
# 2123                         pimco total return fd cl c
# 2124                            dfa us targeted value i
# 2125           ishares barclays short treasury bond fun
# 2126          intercontinentalexchange group div: 3.400
# 2127                     vanguard 500 index investor cl
# 2128                american capital world grth & inc a
# 2129       vanguard short term corp bond index fund etf
# 2130                      union pacific corp div: 2.200
# 2131                              costco wholesale corp
# 2132                     vanguard mid cap index admiral
# 2133                        alexion pharmaceuticals inc
# 2134                               general dynamics crp
# 2135                                          bce inc f
# 2136            prudential jennison natural resources z
# 2137                            delta air lines inc com
# 2138                           cognizant tech solutns a
# 2139  pimco investment grade corporate bond fund - c...
# 2140                                 eli lilly & co com
# 2141                                dfa comm strategy i
#
#                                           description_y ticker_x ticker_y  \
# 0                           first trust dj internet idx      FDN      FDN
# 1     schwab strategic tr fundamental intl large co ...     FNDF     FNDF
# 2                    vanguard small-cap index fund inst    VSMAX    VSCIX
# 3     duke energy corp new com new isin #us26441c204...      DUK      DUK
# 4                                             visa inc.        V        V
# 5                                         ford motor co        F        F
# 6                               united sts stl cp (new)        X        X
# 7                    vanguard total intl bond index etf     BNDX     BNDX
# 8                               schwab us small cap etf     SCHA     SCHA
# 9                                   mfs value fund cl i    MEIIX    MEIIX
# 10                  oppenheimer developing mkts fd cl a    ODMAX    ODMAX
# 11                               genomic health inc com     GHDX     GHDX
# 12             spdr barclays capital international trea      BWX      BWX
# 13                                   kraft heinz co com      KHC      KHC
# 14             vanguard total bond market idx instl pls    VBTLX    VBMPX
# 15                 vanguard interm-term invmt-grade inv    VFICX    VFICX
# 16                             baidu inc spon adr rep a     BIDU     BIDU
# 17                                          novartis ag      NVS      NVS
# 18                              seaspan corporation cmn      SSW      SSW
# 19               vanguard bond index total mkt investor    VBTLX    VBMFX
# 20                              mfs municipal high cl i    MMIIX    MMIIX
# 21                                 metlife incorporated      MET      MET
# 22                      vy clarion real estate port srv    RRESX    IVRSX
# 23                     vanguard short-term invest-grade    VFSUX    VFSIX
# 24                                  spdr s&p 500 etf iv      SPY      SPY
# 25                       fund: pimco total return admin    PTTAX    PTRAX
# 26                                    intel corporation     INTC     INTC
# 27                                 vanguard 500 idx adm    VFIAX    VFIAX
# 28                                 paypal holdings inco     PYPL     PYPL
# 29                    pimco total return fund - class r    PTTRX    PTRRX
# ...                                                 ...      ...      ...
# 2112                                pfizer incorporated      PFE      PFE
# 2113                        pimco income administrative    PONDX    PIINX
# 2114              vanguard mid cap value etf div: 2.308      VOE      VOE
# 2115                               wisdomtree investmnt     WETF     WETF
# 2116                    merrimack pharmaceuticals, inc.     MACK     MACK
# 2117                        ishares russell 1000 gr etf      IWF      IWF
# 2118                         exxon mobil corp | e005207      XOM      XOM
# 2119                     blackrock hi yield bd ptf inst    BHYSX    BHYIX
# 2120             pimco commodity real return strat inst    PCRIX    PCRIX
# 2121                               vang sm cap idx inst    VSMAX    VSCIX
# 2122                                        pg & e corp      PCG      PCG
# 2123                     fund: pimco total return admin    PTTCX    PTRAX
# 2124                         dfa us targeted value fund    DFFVX    DFFVX
# 2125               ishares short-term treasury bond etf      SHV      SHV
# 2126          intercontinental exchange inc com usd0.01      ICE      ICE
# 2127            vanguard 500 index fund investor shares    VFINX    VFINX
# 2128               capital world growth and income fund    CWGIX    CWGIX
# 2129             vanguard short-term corporate bond etf     VCSH     VCSH
# 2130                              union pac corporation      UNP      UNP
# 2131                          costco wholesale corp new     COST     COST
# 2132             vanguard mid capitalization index fund    VIMAX    VIMAX
# 2133                       alexion pharmaceuticals inc.     ALXN     ALXN
# 2134                             genl dynamics corp com       GD       GD
# 2135                                            bce inc      BCE      BCE
# 2136                              prudential jennison ^    PNRZX    PNRZX
# 2137                       delta air lines inc dela new      DAL      DAL
# 2138                      cognizant tech solutions corp     CTSH     CTSH
# 2139                  fid conservative income bond fund    PBDAX    FCONX
# 2140                              lilly eli &co com npv      LLY      LLY
# 2141                        dfa commodity strategy port    DCMSX    DCMSX
#
#      same_security
# 0             True
# 1             True
# 2            False
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13            True
# 14           False
# 15            True
# 16            True
# 17            True
# 18            True
# 19           False
# 20            True
# 21            True
# 22           False
# 23           False
# 24            True
# 25           False
# 26            True
# 27            True
# 28            True
# 29           False
# ...            ...
# 2112          True
# 2113         False
# 2114          True
# 2115          True
# 2116          True
# 2117          True
# 2118          True
# 2119         False
# 2120          True
# 2121         False
# 2122          True
# 2123         False
# 2124          True
# 2125          True
# 2126          True
# 2127          True
# 2128          True
# 2129          True
# 2130          True
# 2131          True
# 2132          True
# 2133          True
# 2134          True
# 2135          True
# 2136          True
# 2137          True
# 2138          True
# 2139         False
# 2140          True
# 2141          True
#
# [2142 rows x 5 columns]
